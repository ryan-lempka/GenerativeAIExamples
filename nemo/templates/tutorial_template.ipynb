# %% [markdown]
# <!-- TEMPLATE: Copy, replace [placeholders], delete this cell when done. Checklist at bottom. -->

# %% [markdown]
# # [Title: Action + Measurable Outcome]
#
# [One sentence: what you'll do and what you'll achieve, with concrete metrics if possible.]
#
# ## Prerequisites
#
# **Hardware:** [Specify GPU requirements, e.g., "1 NVIDIA GPU"]
#
# **Setup:**
#
# 1. **Deploy NeMo Microservices 25.8.0+**: Follow the [Minikube setup guide](https://docs.nvidia.com/nemo/microservices/latest/get-started/setup/minikube/).
#
# 2. **HuggingFace token**: https://huggingface.co/settings/tokens (typically read access). Set `HF_TOKEN` env var or enter when prompted.
#
# 3. **Service URLs**: Typically `http://nemo.test`, `http://data-store.test`, `http://nim.test`.
#
# > **Note:** [Resource management notes - e.g., "This notebook uses 1 GPU sequentially..."]
#
# > **Tip:** Cleanup cells at the end can be uncommented to delete resources.

# %% [markdown]
# ## Overview
#
# [1-2 paragraphs: What problem does this solve? Why does it matter? How does it connect to real-world use cases?]

# %% [markdown]
# ## Objectives
#
# By the end of this notebook, you will:
# - [Specific, measurable outcome 1]
# - [Specific, measurable outcome 2]
# - [Specific, measurable outcome 3]
#
# **Note**: Time estimates are approximate and depend on hardware and cluster configuration.

# %%
# Install dependencies (keep minimal, pin versions for reproducibility)
# %pip install -q [packages]

# %%
# Imports (consolidate ALL imports here - no imports scattered through notebook)
import os
from getpass import getpass
from nemo_microservices import NeMoMicroservices
# [Add your imports here]

# %%
# Configuration - Service URLs (get from: cat /etc/hosts)
NEMO_URL = "http://nemo.test"           # NeMo Platform API
NIM_URL = "http://nim.test"             # NIM Inference API
NDS_URL = "http://data-store.test"      # Data Store API (if needed)

# Credentials - prompts if not set via environment variable
HF_TOKEN = os.environ.get("HF_TOKEN") or getpass("HuggingFace token: ")
NAMESPACE = os.environ.get("NAMESPACE") or input("Namespace (e.g. yourname_tutorial): ")

# %%
# Initialize NeMo client
# base_url: Platform API (training, models, datasets)
# inference_base_url: NIM API (model inference)
nemo = NeMoMicroservices(base_url=NEMO_URL, inference_base_url=NIM_URL)
print("NeMo client initialized")

# %% [markdown]
# ## Step 0: Identify the Opportunity (~X min)
#
# [Show the "before" state - the problem this tutorial solves.]
#
# <!-- Tip: Explain NIM on first use: "NIM (NVIDIA Inference Microservice) serves models via OpenAI-compatible API" -->

# %%
# Demonstrate the baseline/current state
# - Deploy or use existing baseline
# - Run a representative task
# - Show where it struggles or what's missing
# - Capture results for later comparison

# %% [markdown]
# ## Step 1: [First Action] (~X min)
#
# [What this step does and why.]
#
# <!-- Tip: First use of a NeMo service? One sentence: "Data Store holds datasets (HuggingFace-compatible API)" -->

# %%
# Implementation
# - Include progress feedback for operations >30s
# - Handle errors explicitly
# - Comment the "why", not the "what"

# %% [markdown]
# ## Step 2: [Second Action] (~X min)
#
# [Continue the pattern: explain → implement → provide feedback]

# %%
# [Add steps as needed - aim for 4-7 total steps including Step 0]

# %% [markdown]
# ## Step N: See the Improvement
#
# [Compare results to Step 0 baseline. Show concrete before/after metrics or outputs.]
#
# **Goal:** User sees tangible evidence that the tutorial delivered on its promise.

# %%
# Show before/after comparison
# - Use tables or formatted output for clarity
# - Highlight the improvement
# - Connect back to the problem shown in Step 0

# %% [markdown]
# ## Results
#
# [Display final metrics with context. Explain what the numbers mean in plain English.]

# %%
# Format and display results
# - Show baseline vs. final
# - Calculate and display improvement percentage
# - Print endpoint/model info for production use

# %% [markdown]
# ## Summary
#
# [2-3 paragraphs recapping:
# 1. What was built/achieved
# 2. Key insight or learning
# 3. Production readiness - what can the user do with this now?]

# %% [markdown]
# ## Next Steps
#
# **Scale Up:**
# - [How to improve results further]
# - [Larger data, more compute, etc.]
#
# **Apply to Your Domain:**
# - [How to adapt this to user's own data]
# - [Link to data format documentation]
#
# **Learn More:**
# - [NeMo Microservices Documentation](https://docs.nvidia.com/nemo/microservices/latest/)
# - [Related tutorials]

# %% [markdown]
# ---
#
# ## Pre-Publish Checklist
#
# *Run through before publishing. Delete this cell when done.*
#
# **Structure:**
# - [ ] Step 0 shows the problem/baseline
# - [ ] Before/after comparison in results
# - [ ] Time estimates on steps
# - [ ] Granular cleanup (one cell per resource)
#
# **Code:**
# - [ ] All imports at top
# - [ ] Progress feedback for ops >30s
# - [ ] Error handling on API calls
#
# **Content:**
# - [ ] NeMo services explained on first use
# - [ ] Acronyms defined (NIM, NDS, etc.)
# - [ ] Comments explain "why" not "what"
#
# **Final:**
# - [ ] Outputs stripped
# - [ ] 30-40 cells max

# %% [markdown]
# ## Cleanup
#
# Uncomment cells below as needed to delete resources.
#
# [Create one cell per resource type: deployment, model, dataset, config, namespace.
# Order from least destructive to most destructive.
# Add PERMANENT warning for irreversible deletions.]

# %%
# # Delete [resource type] - [impact description]
# # Example: Delete deployment (frees GPU, model retained for redeployment)
# # Example: Delete namespace (PERMANENT - deletes everything)
