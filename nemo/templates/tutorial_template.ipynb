# %% [markdown]
# <!--
# TEMPLATE INSTRUCTIONS (delete this comment when done)
# - Reference: nemo/data-flywheel/embedding-finetuning/embedding_finetuning_local.ipynb
# - Replace all [placeholders] with your content
# - Pre-publish checklist at bottom of notebook
# -->
#
# # [Title]
#
# [Hook sentence. E.g., "Fine-tune an embedding model and improve retrieval by 6-10% in ~1 hour."]
#
# ## Prerequisites
#
# **Hardware:** [X NVIDIA GPU(s)]
#
# **Setup Steps:**
#
# 1. **Deploy NeMo Microservices**: Follow the [Minikube setup guide](https://docs.nvidia.com/nemo/microservices/latest/get-started/setup/minikube/).
#
# 3. **HuggingFace token**: https://huggingface.co/settings/tokens (typically read access). Set `HF_TOKEN` env var or enter when prompted.
#
# 4. **Service URLs**: Run `cat /etc/hosts` to find hostnames if NMP deployed vis Minikube setup guide (typically `http://nemo.test`, `http://data-store.test`, `http://nim.test`).
#
# > **Tip:** Cleanup cells at the end of the notebook can be uncommented to delete resources.

# %% [markdown]
# ## Overview
#
# **Use case:** [What problem this solves]
#
# **Real-world workflow:** [How this fits into production pipelines]
#
# **This notebook:** [What steps we'll walk through]

# %% [markdown]
# ## Objectives
#
# By the end of this notebook, you will:
# - [Specific outcome 1]
# - [Specific outcome 2]
# - [Specific outcome 3]

# %%
# Install dependencies
# %pip install -q nemo-microservices

# %%
# Imports (consolidate ALL imports here)
import os
from getpass import getpass
from nemo_microservices import NeMoMicroservices

# %%
# Configuration
NEMO_URL = "http://nemo.test"
NIM_URL = "http://nim.test"
NDS_URL = "http://data-store.test"

HF_TOKEN = os.environ.get("HF_TOKEN") or getpass("HuggingFace token: ")
NAMESPACE = os.environ.get("NAMESPACE") or input("Namespace: ")

# %%
# Initialize client
nemo = NeMoMicroservices(base_url=NEMO_URL, inference_base_url=NIM_URL)
print("NeMo client initialized")

# %% [markdown]
# ## Step 0: Identify the Opportunity (~X min)
#
# [Show the baseline - what's the current state and where does it fall short?]

# %%
# Baseline demonstration

# %% [markdown]
# ## Step 1: [Action] (~X min)
#
# [Brief explanation.]

# %%
# Implementation

# %% [markdown]
# ## Step 2: [Action] (~X min)
#
# [Brief explanation.]

# %%
# Implementation

# %% [markdown]
# ## Step N: See the Improvement
#
# [Compare to Step 0 baseline. Show before/after.]

# %%
# Before/after comparison

# %% [markdown]
# ## Results
#
# [Final metrics with context.]

# %%
# Display results

# %% [markdown]
# ## Summary
#
# [What was built, key insight, what user can do next.]

# %% [markdown]
# ## Next Steps
#
# **Scale up:** [Improve results with more data/compute]
#
# **Apply to your domain:** [How to adapt to user's data]
#
# **Learn more:** [NeMo Microservices Documentation](https://docs.nvidia.com/nemo/microservices/latest/)

# %% [markdown]
# ## Cleanup
#
# Uncomment to delete resources. One cell per resource type.

# %%
# Add one cell per resource with code to delete and comment out code

# %% [markdown]
# ---
#
# ## Pre-Publish Checklist
#
# *Delete this cell when done.*
#
# **Structure**
# - Step 0 shows baseline
# - Before/after comparison
# - Time estimates on steps
# - Granular cleanup cells
#
# **Code**
# - All imports at top
# - Progress feedback for long running cells
# - No magic numbers - use variables for configuration items (e.g. LEARNING_RATE)
# - Concise and leverages third party libraries as needed to reduce boilerplate
#
# **Content**
# - NeMo services explained on first use
# - Acronyms defined on first use
# - Comments explain "why"
# - All markdown and comments are concise
#
# **Final**
# - Outputs stripped
# - 40 cells max is ideal
